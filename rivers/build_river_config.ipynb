# %%
from configs.config_object import ConfigObject
from rivers import build_river_config

# %%
config = ConfigObject('..//config.json')
output_dir = fr'C:\Users\leroquan\Documents\Data\mitgcm_grids\lucerne\100m'
river_dicts, river_string = build_river_config(config, output_dir)

# %%
config.rivers[0].name
# Out:
# 'reuss-seedorf'
